# %%
import numpy as np
import json

class args:
    num_cand = 19

def read_json(file):
    with open(file) as f:
        return json.load(f)

data_ml_100k = read_json("ml_100k.json")


u_item_dict = {}
u_item_p = 0
for elem in data_ml_100k:
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in u_item_dict:
            u_item_dict[movie] = u_item_p
            u_item_p +=1
print (len(u_item_dict))
u_item_len = len(u_item_dict)

user_list = []
for i, elem in  enumerate(data_ml_100k):
    item_hot_list = [0 for ii in range(u_item_len)]
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        item_pos = u_item_dict[movie]
        item_hot_list[item_pos] = 1
    user_list.append(item_hot_list)
user_matrix = np.array(user_list)
user_matrix_sim = np.dot(user_matrix, user_matrix.transpose())
        
        
        
i_item_dict = {}
i_item_id_list = []
i_item_user_dict = {}
i_item_p = 0
for i, elem in  enumerate(data_ml_100k):
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in i_item_user_dict:
            item_hot_list = [0. for ii in range(len(data_ml_100k))]
            i_item_user_dict[movie] = item_hot_list
            i_item_dict[movie] = i_item_p
            i_item_id_list.append(movie)
            i_item_p+=1
#         item_pos = item_dict[movie]
        i_item_user_dict[movie][i] += 1
#     user_list.append(item_hot_list)
i_item_s_list = []
for item in i_item_id_list:
    i_item_s_list.append(i_item_user_dict[item])
#     print (sum(item_user_dict[item]))
item_matrix = np.array(i_item_s_list)
item_matrix_sim = np.dot(item_matrix, item_matrix.transpose())

id_list =list(range(0,len(data_ml_100k)))



### item filtering
def soft_if_items(target_seq, num_i=12, total_i=args.num_cand, item_matrix_sim=item_matrix_sim, item_dict=i_item_dict):
    candidate_movies_dict = {} 
    for movie in target_seq:
        sorted_is = sorted(list(enumerate(item_matrix_sim[item_dict[movie]])), key=lambda x: x[-1], reverse=True)[:num_i]
        for is_i, is_v in sorted_is:
            s_item = i_item_id_list[is_i]
            
            if s_item not in target_seq:
                if s_item not in candidate_movies_dict:
                    candidate_movies_dict[s_item] = 0.
                candidate_movies_dict[s_item] += is_v
#             print (item_id_list[is_i], candidate_movies_dict)
    candidate_pairs = list(sorted(candidate_movies_dict.items(), key=lambda x:x[-1], reverse=True))
    candidate_items = [e[0] for e in candidate_pairs][:total_i]
    return candidate_items

results_data_15 = []
num_u= 12
total_i = args.num_cand
count = 0
total = 0
cand_ids = []
for i in id_list[:1000]:
    elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')
    
    candidate_items = soft_if_items(seq_list)

    print(len(candidate_items))
    
    if elem[-1] in candidate_items:
#         print ('HIT: 1')
        count += 1
        cand_ids.append(i)
    else:
        pass
#         print ('HIT: 0')
    total +=1
print (f'count/total:{count}/{total}={count*1.0/total}')
# Out:
# 1493
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 14
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 18
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 12
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 13
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 18
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 13
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 13
# 17
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 12
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 13
# 19
# 14
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 13
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 14
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 12
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 11
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 16
# 19
# 19
# 19
# 14
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 16
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 18
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 16
# 16
# 19
# 19
# 14
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 18
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 18
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 14
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 18
# 19
# 19
# 19
# 19
# 19
# 10
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 12
# 19
# 19
# 18
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 14
# 19
# 19
# 19
# 19
# 19
# 17
# 14
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 10
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 13
# 19
# 19
# 19
# 17
# 19
# 19
# 18
# 19
# 19
# 19
# 19
# 19
# 18
# 19
# 19
# 19
# 19
# 16
# 19
# 19
# 19
# 19
# 19
# 19
# 15
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# count/total:142/943=0.15058324496288442
